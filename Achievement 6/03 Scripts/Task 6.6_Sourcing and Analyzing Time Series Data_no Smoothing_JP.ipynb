# %% [markdown]
# # 01. Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import statsmodels.api as sm
import warnings

warnings.filterwarnings("ignore")

plt.style.use('fivethirtyeight')

# %% [markdown]
# # 02. Import Data

# %%
# Folder Path
path = r'C:\Users\jrper\OneDrive\Documents\Career Foundry Data Analytics Program\Achievement 6'

# %%
# Import trips_wrangled_no_outliers2.csv
df_trips = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'trips_wrangled_no_outliers2.csv'), index_col = False)

# %% [markdown]
# # 03. Explore Data

# %%
# View first 5 rows for df_trips
df_trips.head()
# Out:
#    Unnamed: 0  tripduration                starttime                 stoptime  \
# 0           0           226  2020-01-01 00:04:50.192  2020-01-01 00:08:37.037
# 1           1           377  2020-01-01 00:16:01.670  2020-01-01 00:22:19.080
# 2           2           288  2020-01-01 00:17:33.877  2020-01-01 00:22:22.442
# 3           3           435  2020-01-01 00:32:05.902  2020-01-01 00:39:21.066
# 4           4           231  2020-01-01 00:46:19.678  2020-01-01 00:50:11.344
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  ...  \
# 0               -74.043117            3211        Newark Ave  ...
# 1               -74.043117            3269   Brunswick & 6th  ...
# 2               -74.043117            3269   Brunswick & 6th  ...
# 3               -74.063913            3280       Astor Place  ...
# 4               -74.043117            3276  Marin Light Rail  ...
#
#    weekday_stoptime  month_name_starttime  month_name_stoptime hour_starttime  \
# 0         Wednesday               January              January              0
# 1         Wednesday               January              January              0
# 2         Wednesday               January              January              0
# 3         Wednesday               January              January              0
# 4         Wednesday               January              January              0
#
#    hour_stoptime customer_age  starttime_counts  tripduration_minutes  \
# 0              0           36             25629              3.766667
# 1              0           31             25629              6.283333
# 2              0           31             25629              4.800000
# 3              0           51             15767              7.250000
# 4              0           37             25629              3.850000
#
#    tripduration_hours  tripduration_buckets
# 0            0.062778    10 minutes or less
# 1            0.104722    10 minutes or less
# 2            0.080000    10 minutes or less
# 3            0.120833    10 minutes or less
# 4            0.064167    10 minutes or less
#
# [5 rows x 33 columns]

# %%
# Drop 'Unnamed: 0' column
df_trips.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
# View df_trips row and column count
df_trips.shape
# Out:
# (379861, 32)

# %%
# Convert 'starttime' and 'stoptime' columns to datetime instead of object
df_trips['starttime'] = pd.to_datetime(df_trips['starttime'])
df_trips['stoptime'] = pd.to_datetime(df_trips['stoptime'])

# %%
# View df_trips column datatypes
df_trips.dtypes
# Out:
# tripduration                        int64
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# start station id                    int64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                      int64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                             object
# day_of_month_starttime              int64
# month_starttime                     int64
# year_starttime                      int64
# day_of_month_stoptime               int64
# month_stoptime                      int64
# year_stoptime                       int64
# weekday_starttime                  object
# weekday_stoptime                   object
# month_name_starttime               object
# month_name_stoptime                object
# hour_starttime                      int64
# hour_stoptime                       int64
# customer_age                        int64
# starttime_counts                    int64
# tripduration_minutes              float64
# tripduration_hours                float64
# tripduration_buckets               object
# dtype: object

# %% [markdown]
# # 04. Time Series Analysis

# %% [markdown]
# ## Prepare Data for Time Series Analysis

# %%
# Extract date from datetime column
df_trips['starttime_date'] = df_trips['starttime'].dt.date

# %%
# View new 'starttime_date' column
df_trips['starttime_date'].head()
# Out:
# 0    2020-01-01
# 1    2020-01-01
# 2    2020-01-01
# 3    2020-01-01
# 4    2020-01-01
# Name: starttime_date, dtype: object

# %%
# Check datatype for 'starttime_date' column
df_trips['starttime_date'].dtype
# Out:
# dtype('O')

# %% [markdown]
# #### Observations: Datatype will need to be changed to datetime for time series analysis.

# %%
# Create dataframe for time series analysis by aggregating 'starttime_date' counts, rename new column for clarity, and reset index.
data = df_trips.groupby(['starttime_date']).agg({'starttime_date': 'count'}).rename(columns={'starttime_date':'startdate_counts'}).reset_index()

# %%
# Ensure new dataframe was successfully created.
data
# Out:
#     starttime_date  startdate_counts
# 0       2020-01-01               370
# 1       2020-01-02               892
# 2       2020-01-03               772
# 3       2020-01-04               566
# 4       2020-01-05               501
# ..             ...               ...
# 480     2021-04-26               759
# 481     2021-04-27               888
# 482     2021-04-28              1190
# 483     2021-04-29               841
# 484     2021-04-30               781
#
# [485 rows x 2 columns]

# %%
from datetime import datetime

# Create datetime column from 'starttime_date'
data['startdate'] = pd.to_datetime(data['starttime_date'])

# Set datetime as the index of dataframe.
data = data.set_index('startdate') 

# Drop 'starttime_date' column
data.drop(['starttime_date'], axis=1, inplace=True)

# View new dataframe
data.head()
# Out:
#             startdate_counts
# startdate
# 2020-01-01               370
# 2020-01-02               892
# 2020-01-03               772
# 2020-01-04               566
# 2020-01-05               501

# %%
# Plot new data set

sns.set(rc={'figure.figsize':(15, 5)})
sns.lineplot(
    x ='startdate',
    y ='startdate_counts',
    data = data )
plt.show()

# %% [markdown]
# ## Decomposition

# %%
# Specify frequency for decomposition model. Data is daily, or 'd'.
data = data.asfreq('d')

# %%
# Check for missing values
data.isnull().sum()
# Out:
# startdate_counts    1
# dtype: int64

# %% [markdown]
# #### Observations: There is one missing value after defining frequency. Fill in using 'bfill', 'ffill'.

# %%
# Fill in missing value 
data = data.fillna(method='bfill').fillna(method='ffill')

# %%
# Ensure missing value has been resolved.
data.isnull().sum()
# Out:
# startdate_counts    0
# dtype: int64

# %% [markdown]
# #### There are no more missing values.

# %%
# Decompose time series using an additive model
decomposition = sm.tsa.seasonal_decompose(data, model='additive')

# %%
# Define fixed size for all special charts.

from pylab import rcParams
rcParams['figure.figsize'] = 18, 7

# %%
# Plot separate components
decomposition.plot()
plt.show()

# %% [markdown]
# #### Observations: There is seasonality with a larger number of trips in the summer and a decrease in trips taken during the winter. The decrease during the spring of 2020 is likely due to the Covid-19 quarantine. There is also a significant residual, or unexplained noise.

# %% [markdown]
# ## Test for Stationarity

# %%
# Import adfuller() function
from statsmodels.tsa.stattools import adfuller 

# Define function

def dickey_fuller(timeseries): 
    # Perform the Dickey-Fuller test:
    
    print ('Dickey-Fuller Stationarity test:')
    test = adfuller(timeseries, autolag='AIC')
    result = pd.Series(test[0:4], index=['Test Statistic','p-value','Number of Lags Used','Number of Observations Used'])
    for key,value in test[4].items():
       result['Critical Value (%s)'%key] = value
    print (result)

# Apply test using function on time series
dickey_fuller(data)
# Out:
# Dickey-Fuller Stationarity test:
# Test Statistic                  -1.236551
# p-value                          0.657678
# Number of Lags Used             15.000000
# Number of Observations Used    470.000000
# Critical Value (1%)             -3.444340
# Critical Value (5%)             -2.867709
# Critical Value (10%)            -2.570056
# dtype: float64

# %% [markdown]
# #### Observations:
# #### Null Hypothesis: A unit root is present.
# #### Alternative Hypothesis: A unit root is not present.
# #### The test statistic is larger than all of the critical values, so the null hypothesis cannot be rejected and the data is non-stationary.
# #### The p-value is much larger than 0.05 which does not indicate a significant test result.

# %% [markdown]
# ## Stationarize Data

# %%
# Differencing: The df.shift(1) function turns observation to t-1
data_diff = data - data.shift(1)

# %%
# Remove missing values from differencing for Dickey-Fuller test.
data_diff.dropna(inplace = True)

# %%
# View data_diff
data_diff.head()
# Out:
#             startdate_counts
# startdate
# 2020-01-02             522.0
# 2020-01-03            -120.0
# 2020-01-04            -206.0
# 2020-01-05             -65.0
# 2020-01-06             431.0

# %%
# Plot data_diff

sns.set(rc={'figure.figsize':(15, 5)})
sns.lineplot(
    x ='startdate',
    y ='startdate_counts',
    data = data_diff )
plt.show()

# %%
# Dickey Fuller test for data_diff
dickey_fuller(data_diff)
# Out:
# Dickey-Fuller Stationarity test:
# Test Statistic                  -5.544654
# p-value                          0.000002
# Number of Lags Used             17.000000
# Number of Observations Used    467.000000
# Critical Value (1%)             -3.444431
# Critical Value (5%)             -2.867749
# Critical Value (10%)            -2.570077
# dtype: float64

# %% [markdown]
# #### Observations: The test statistic is now smaller than all of the critical values, so the null hypothesis can be rejected with 99% confidence and the data is now stationary. The p-value is much less than 0.05 which indicates a significant test result.

# %% [markdown]
# ## Check Autocorrelations

# %%
# Import autocorrelation and partial correlation plots
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf 

# Plot autocorrelations before differencing
plot_acf(data)
plt.show()

# %% [markdown]
# #### Observations: There are 28 lags beyond the confidence interval which shows that the data is non-stationary.

# %%
# Plot autocorrelations after differencing
plot_acf(data_diff)
plt.show()

# %% [markdown]
# #### Observations: After differencing, there are 12 lags beyond the confidence interval which suggests weak stationarity.
