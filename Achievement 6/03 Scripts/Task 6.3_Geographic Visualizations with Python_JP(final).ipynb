# %% [markdown]
# # 01. Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import os
import folium
import geojson

# %% [markdown]
# # 02. Import Data

# %%
# Folder Path
path = r'C:\Users\jrper\OneDrive\Documents\Career Foundry Data Analytics Program\Achievement 6'

# %%
# Import trips_merged_cleaned.csv
df_trips = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'trips_merged_cleaned.csv'), index_col = False)

# %%
# Import Choropleth2.csv
df_choropleth = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Choropleth2.csv'), index_col = False)

# %%
# Import geojson file for Citi Bike locations 
station_geo = r'C:\Users\jrper\OneDrive\Documents\Career Foundry Data Analytics Program\Achievement 6\02 Data\Original Data\citi_bike_locations.geojson'

# %%
# Display charts in notebook
# %matplotlib inline

# %%
# View geojson file contents
f = open(r'C:\Users\jrper\OneDrive\Documents\Career Foundry Data Analytics Program\Achievement 6\02 Data\Original Data\citi_bike_locations.geojson')

# geojson object asa dictionary
data = geojson.load(f)
  
# Iterating through the geojson list
for i in data['features']:
    print(i)
# Out:
# {"geometry": {"coordinates": [-74.037665, 40.715256, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7152561007, "lon": -74.0376649783}, "location": "Grand St", "stationid": "JC102"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.040945, 40.716471, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7164706135, "lon": -74.0409454012}, "location": "York St", "stationid": "JC096"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.043918, 40.717722, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7177223148, "lon": -74.0439179821}, "location": "City Hall", "stationid": "JC003"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.050944, 40.719472, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7194722155, "lon": -74.0509438064}, "location": "Montgomery St", "stationid": "JC099"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.050661, 40.724136, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7241359102, "lon": -74.0506611641}, "location": "Brunswick St", "stationid": "JC023"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.050371, 40.726014, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7260144579, "lon": -74.0503711466}, "location": "Brunswick & 6th", "stationid": "JC081"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.048866, 40.725686, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7256857279, "lon": -74.0488656996}, "location": "Monmouth and 6th", "stationid": "JC075"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.062848, 40.713512, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7135120939, "lon": -74.0628481969}, "location": "Lafayette Park (Inactive)", "stationid": "JC078"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.078935, 40.711068, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7110678798, "lon": -74.0789352196}, "location": "Jackson Square", "stationid": "JC063"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.057319, 40.745956, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7459562266, "lon": -74.0573191416}, "location": "Leonard Gordon Park", "stationid": "JC080"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.038406, 40.712448, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7124476111, "lon": -74.038406334}, "location": "Morris Canal (Inactive)", "stationid": "JC072"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.0429, 40.714588, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7145875949, "lon": -74.0428995978}, "location": "Marin Light Rail", "stationid": "JC013"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.03342, 40.714147, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7141471231, "lon": -74.0334200078}, "location": "Paulus Hook", "stationid": "JC002"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.049915, 40.721637, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7216371247, "lon": -74.0499148313}, "location": "Dixon Mills", "stationid": "JC076"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.046197, 40.721522, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7215223283, "lon": -74.0461973023}, "location": "Newark Ave", "stationid": "JC032"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.045562, 40.725277, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7252769566, "lon": -74.0455622209}, "location": "Jersey & 6th St", "stationid": "JC027"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.044171, 40.727577, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7275774639, "lon": -74.0441708488}, "location": "Hamilton Park", "stationid": "JC009"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.046709, 40.735454, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7354538976, "lon": -74.0467094593}, "location": "Hoboken Ave at Monmouth St", "stationid": "JC105"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.078358, 40.724559, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7245586347, "lon": -74.0783581962}, "location": "Lincoln Park", "stationid": "JC053"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.072192, 40.72583, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7258298491, "lon": -74.0721915749}, "location": "Fairmount Ave", "stationid": "JC093"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.064173, 40.723718, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7237181889, "lon": -74.0641728983}, "location": "Baldwin at Montgomery", "stationid": "JC020"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.07088, 40.727516, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7275156388, "lon": -74.0708797296}, "location": "Glenwood Ave", "stationid": "JC094"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.064188, 40.730887, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7308868716, "lon": -74.0641877617}, "location": "Sip Ave", "stationid": "JC056"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.062773, 40.733752, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7337518542, "lon": -74.0627729363}, "location": "Journal Square", "stationid": "JC103"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.04926, 40.716552, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7165517589, "lon": -74.0492600041}, "location": "JC Medical Center", "stationid": "JC011"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.047772, 40.718541, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7185408794, "lon": -74.0477715891}, "location": "Van Vorst Park", "stationid": "JC035"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.04308, 40.719601, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7196009179, "lon": -74.0430804908}, "location": "Grove St PATH", "stationid": "JC005"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.042767, 40.721645, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.721645059, "lon": -74.042767344}, "location": "Manila & 1st", "stationid": "JC082"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.045896, 40.723318, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7233180824, "lon": -74.045895899}, "location": "Jersey & 3rd", "stationid": "JC074"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.067608, 40.725358, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7253581329, "lon": -74.0676076876}, "location": "McGinley Square", "stationid": "JC055"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.052544, 40.737685, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7376854903, "lon": -74.0525435583}, "location": "Oakland Ave", "stationid": "JC022"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.032717, 40.716841, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7168406398, "lon": -74.032717438}, "location": "Columbus Dr at Exchange Pl", "stationid": "JC106"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.038916, 40.718314, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7183141708, "lon": -74.0389157689}, "location": "Columbus Drive", "stationid": "JC014"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.035345, 40.724341, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7243406681, "lon": -74.035345214}, "location": "Washington St", "stationid": "JC098"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.033772, 40.727139, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7271390963, "lon": -74.0337720463}, "location": "Newport PATH", "stationid": "JC066"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.055696, 40.711265, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7112648878, "lon": -74.0556955773}, "location": "Liberty Light Rail", "stationid": "JC052"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.08375, 40.718236, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7182357773, "lon": -74.083749766}, "location": "Union St", "stationid": "JC051"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.071262, 40.719344, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7193439289, "lon": -74.0712622874}, "location": "Astor Place", "stationid": "JC077"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.071525, 40.722151, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7221505459, "lon": -74.0715247225}, "location": "Bergen Ave", "stationid": "JC095"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.057502, 40.731059, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7310590298, "lon": -74.0575019391}, "location": "Hilltop", "stationid": "JC019"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.059336, 40.734923, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7349233256, "lon": -74.0593360409}, "location": "5 Corners Library", "stationid": "JC018"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.050345, 40.73469, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7346896674, "lon": -74.0503446918}, "location": "Christ Hospital", "stationid": "JC034"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.043991, 40.744384, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7443841109, "lon": -74.043991365}, "location": "Riverview Park", "stationid": "JC057"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.036506, 40.712822, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7128223252, "lon": -74.0365055784}, "location": "Essex Light Rail", "stationid": "JC038"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.038116, 40.721168, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7211684255, "lon": -74.0381161643}, "location": "Warren St", "stationid": "JC006"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.034236, 40.719247, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.719246961, "lon": -74.034236042}, "location": "Harborside", "stationid": "JC104"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.032008, 40.728727, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7287268001, "lon": -74.0320084111}, "location": "Newport Pkwy", "stationid": "JC008"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.06659, 40.7144, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7143995893, "lon": -74.0665900806}, "location": "Communipaw & Berry Lane", "stationid": "JC084"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.067094, 40.737763, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7377628048, "lon": -74.0670943237}, "location": "Dey St", "stationid": "JC065"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.051637, 40.742767, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7427671767, "lon": -74.0516366262}, "location": "Pershing Field", "stationid": "JC024"}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.040432, 40.74872, 0.0], "type": "Point"}, "properties": {"geo_point_2d": {"lat": 40.7487195621, "lon": -74.0404321205}, "location": "Heights Elevator", "stationid": "JC059"}, "type": "Feature"}

# %% [markdown]
# # 03. Wrangling Procedures

# %%
# View first 5 rows of df_trips
df_trips.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1           377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2           288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3           435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4           231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# 1               -74.043117            3269   Brunswick & 6th
# 2               -74.043117            3269   Brunswick & 6th
# 3               -74.063913            3280       Astor Place
# 4               -74.043117            3276  Marin Light Rail
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.721525             -74.046305   29444  Subscriber
# 1             40.726012             -74.050389   26305  Subscriber
# 2             40.726012             -74.050389   29268    Customer
# 3             40.719282             -74.071262   29278    Customer
# 4             40.714584             -74.042817   29276  Subscriber
#
#    birth year  gender
# 0        1984       2
# 1        1989       2
# 2        1989       1
# 3        1969       0
# 4        1983       2

# %%
# Convert 'starttime' and 'stoptime' columns to datetime instead of object
df_trips['starttime'] = pd.to_datetime(df_trips['starttime'])
df_trips['stoptime'] = pd.to_datetime(df_trips['stoptime'])

# %%
# Ensure datatype successfully changed
df_trips.dtypes
# Out:
# tripduration                        int64
# starttime                  datetime64[ns]
# stoptime                   datetime64[ns]
# start station id                    int64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                      int64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# dtype: object

# %% [markdown]
# #### Observations: Datatype successfully changed to datetime for 'starttime' and 'stoptime' columns.

# %%
# Extract day, month, and year from 'starttime' and 'stoptime' columns
df_trips['day_of_month_starttime'] = df_trips['starttime'].dt.day
df_trips['month_starttime'] = df_trips['starttime'].dt.month
df_trips['year_starttime'] = df_trips['starttime'].dt.year

df_trips['day_of_month_stoptime'] = df_trips['stoptime'].dt.day
df_trips['month_stoptime'] = df_trips['stoptime'].dt.month
df_trips['year_stoptime'] = df_trips['stoptime'].dt.year

# %%
# Create columns showing weekday name and month name for 'starttime' and 'stoptime' columns
df_trips['weekday_starttime'] = df_trips['starttime'].dt.day_name()
df_trips['weekday_stoptime'] = df_trips['stoptime'].dt.day_name()

df_trips['month_name_starttime'] = df_trips['starttime'].dt.month_name()
df_trips['month_name_stoptime'] = df_trips['stoptime'].dt.month_name()

# %%
# Extract hour of day for 'starttime' and 'stoptime' columns
df_trips['hour_starttime'] = df_trips['starttime'].dt.hour
df_trips['hour_stoptime'] = df_trips['stoptime'].dt.hour

# %%
# Create 'customer_age' column
df_trips['customer_age'] = df_trips['year_starttime'] - df_trips['birth year']

# %%
# Create column showing starttime counts
df_trips['starttime_counts'] = df_trips.groupby(['start station name'])['starttime'].transform('count')

# %%
df_trips['starttime_counts'].describe()
# Out:
# count    379861.000000
# mean      11579.704184
# std        6657.892034
# min           1.000000
# 25%        6035.000000
# 50%       10489.000000
# 75%       15767.000000
# max       25629.000000
# Name: starttime_counts, dtype: float64

# %%
# Create buckets for 'starttime_counts'
df_trips.loc[df_trips['starttime_counts'] <= 2000, 'starttime_buckets'] = 'Lowest Traffic'
df_trips.loc[(df_trips['starttime_counts'] > 2000) & (df_trips['starttime_counts'] <= 4000), 'starttime_buckets'] = 'Low Traffic'
df_trips.loc[(df_trips['starttime_counts'] > 4000) & (df_trips['starttime_counts'] <= 8000), 'starttime_buckets'] = 'Medium Traffic'
df_trips.loc[(df_trips['starttime_counts'] > 8000) & (df_trips['starttime_counts'] <= 10000), 'starttime_buckets'] = 'Medium High Traffic'
df_trips.loc[df_trips['starttime_counts'] > 10000, 'starttime_buckets'] = 'Highest Traffic'

# %%
# Ensure all new columns were successfully created
df_trips.head()
# Out:
#    tripduration               starttime                stoptime  \
# 0           226 2020-01-01 00:04:50.192 2020-01-01 00:08:37.037
# 1           377 2020-01-01 00:16:01.670 2020-01-01 00:22:19.080
# 2           288 2020-01-01 00:17:33.877 2020-01-01 00:22:22.442
# 3           435 2020-01-01 00:32:05.902 2020-01-01 00:39:21.066
# 4           231 2020-01-01 00:46:19.678 2020-01-01 00:50:11.344
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# 1               -74.043117            3269   Brunswick & 6th
# 2               -74.043117            3269   Brunswick & 6th
# 3               -74.063913            3280       Astor Place
# 4               -74.043117            3276  Marin Light Rail
#
#    end station latitude  ...  year_stoptime  weekday_starttime  \
# 0             40.721525  ...           2020          Wednesday
# 1             40.726012  ...           2020          Wednesday
# 2             40.726012  ...           2020          Wednesday
# 3             40.719282  ...           2020          Wednesday
# 4             40.714584  ...           2020          Wednesday
#
#   weekday_stoptime  month_name_starttime  month_name_stoptime  hour_starttime  \
# 0        Wednesday               January              January               0
# 1        Wednesday               January              January               0
# 2        Wednesday               January              January               0
# 3        Wednesday               January              January               0
# 4        Wednesday               January              January               0
#
#    hour_stoptime  customer_age  starttime_counts  starttime_buckets
# 0              0            36             25629    Highest Traffic
# 1              0            31             25629    Highest Traffic
# 2              0            31             25629    Highest Traffic
# 3              0            51             15767    Highest Traffic
# 4              0            37             25629    Highest Traffic
#
# [5 rows x 30 columns]

# %%
# Ensure all new columns were successfully created
df_trips.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender', 'day_of_month_starttime', 'month_starttime',
#        'year_starttime', 'day_of_month_stoptime', 'month_stoptime',
#        'year_stoptime', 'weekday_starttime', 'weekday_stoptime',
#        'month_name_starttime', 'month_name_stoptime', 'hour_starttime',
#        'hour_stoptime', 'customer_age', 'starttime_counts',
#        'starttime_buckets'],
#       dtype='object')

# %% [markdown]
# #### Observations: All new columns were successfully created.

# %% [markdown]
# # 04. Choropleth Map

# %%
# Create dataframe of data to plot
data_to_plot = df_trips[['start station name','starttime_counts']]

# %%
# View subset
data_to_plot.head()
# Out:
#   start station name  starttime_counts
# 0      Grove St PATH             25629
# 1      Grove St PATH             25629
# 2      Grove St PATH             25629
# 3            Sip Ave             15767
# 4      Grove St PATH             25629

# %%
# Setup a folium map at a high-level zoom
map = folium.Map(location = [40.693943, -73.985880], zoom_start = 10.0)
folium.Choropleth(
    geo_data = station_geo, 
    data = data_to_plot,
    columns = ['start station name', 'starttime_counts'],
    key_on = 'properties.location',
    fill_color = 'YlOrBr', fill_opacity=0.6, line_opacity=0.1,
    legend_name = "tripduration").add_to(map)

folium.LayerControl().add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1641f25c6493fe1b8e4cea8ec15406ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1641f25c6493fe1b8e4cea8ec15406ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1641f25c6493fe1b8e4cea8ec15406ff = L.map(
#                 &quot;map_1641f25c6493fe1b8e4cea8ec15406ff&quot;,
#                 {
#                     center: [40.693943, -73.98588],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10.0,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8078cd02c190a2fbab138cb923f5e8a1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1641f25c6493fe1b8e4cea8ec15406ff);
#
#
#             var choropleth_2d9404b371b1391769ea3b0aedd7bca3 = L.featureGroup(
#                 {}
#             ).addTo(map_1641f25c6493fe1b8e4cea8ec15406ff);
#
#
#         function geo_json_69ccd9dc449cfad734ac3c6fa2aa5f12_styler(feature) {
#             switch(feature.properties.location) {
#                 case &quot;Grand St&quot;: case &quot;Montgomery St&quot;: case &quot;Brunswick St&quot;: case &quot;Brunswick \u0026 6th&quot;: case &quot;Monmouth and 6th&quot;: case &quot;Dixon Mills&quot;: case &quot;Jersey \u0026 6th St&quot;: case &quot;Hoboken Ave at Monmouth St&quot;: case &quot;Lincoln Park&quot;: case &quot;Baldwin at Montgomery&quot;: case &quot;Van Vorst Park&quot;: case &quot;Manila \u0026 1st&quot;: case &quot;Jersey \u0026 3rd&quot;: case &quot;McGinley Square&quot;: case &quot;Columbus Drive&quot;: case &quot;Essex Light Rail&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fee391&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;City Hall&quot;: case &quot;Paulus Hook&quot;: case &quot;Newark Ave&quot;: case &quot;JC Medical Center&quot;: case &quot;Washington St&quot;: case &quot;Warren St&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fec44f&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;Lafayette Park (Inactive)&quot;: case &quot;Morris Canal (Inactive)&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;Marin Light Rail&quot;: case &quot;Hamilton Park&quot;: case &quot;Sip Ave&quot;: case &quot;Columbus Dr at Exchange Pl&quot;: case &quot;Newport PATH&quot;: case &quot;Harborside&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fe9929&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;Grove St PATH&quot;: case &quot;Newport Pkwy&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#993404&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;Liberty Light Rail&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d95f0e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffd4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_69ccd9dc449cfad734ac3c6fa2aa5f12_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_69ccd9dc449cfad734ac3c6fa2aa5f12 = L.geoJson(null, {
#                 onEachFeature: geo_json_69ccd9dc449cfad734ac3c6fa2aa5f12_onEachFeature,
#
#                 style: geo_json_69ccd9dc449cfad734ac3c6fa2aa5f12_styler,
#         });
#
#         function geo_json_69ccd9dc449cfad734ac3c6fa2aa5f12_add (data) {
#             geo_json_69ccd9dc449cfad734ac3c6fa2aa5f12
#                 .addData(data)
#                 .addTo(choropleth_2d9404b371b1391769ea3b0aedd7bca3);
#         }
#             geo_json_69ccd9dc449cfad734ac3c6fa2aa5f12_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [-74.03766497832352, 40.715256100740966, 0.0], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;geo_point_2d&quot;: {&quot;lat&quot;: 40.7152561007, &quot;lon&quot;: -74.0376649783}, &quot;location&quot;: &quot;Grand St&quot;, &quot;stationid&quot;: &quot;JC102&quot;}, &quot;type&quot

# %% [markdown]
# #### Observations: Markers appear on the map to represent Citi Bike stations, but there aren't different colors to indicate station popularity.

# %% [markdown]
# ### Assign marker color and popup based on 'start station name' and 'starttime_buckets'

# %%
# Generate base map for New Jersey
def generateBaseMap(default_location=[40.693943, -73.985880], default_zoom_start=10): 
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start, width='50%', height='50%') 
    return base_map

# %%
# Call base map function
new_jersey_map = generateBaseMap()
new_jersey_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ebbbad242c1197043889592e3d3f633 {
#                     position: relative;
#                     width: 50.0%;
#                     height: 50.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ebbbad242c1197043889592e3d3f633&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ebbbad242c1197043889592e3d3f633 = L.map(
#                 &quot;map_2ebbbad242c1197043889592e3d3f633&quot;,
#                 {
#                     center: [40.693943, -73.98588],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2ebbbad242c1197043889592e3d3f633);
#
#
#
#
#
#             var tile_layer_698f7c4ade7b9c302a783c5bb1f2d0a9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2ebbbad242c1197043889592e3d3f633);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Choose station icon colors based on 'starttime_buckets' column values
station_color = {'Lowest Traffic':'white', 'Low Traffic':'lightblue', 'Medium Traffic':'blue', 'Medium High Traffic':'darkblue', 'Highest Traffic':'black'} 

# Loop through each row in dataframe
for i,row in df_choropleth.iterrows():
    # Define popup content
    iframe = folium.IFrame(f'Start Station Name: {str(row["start station name"])} \n Traffic: {str(row["starttime_buckets"])}')
    
    # Initialize popup using iframe
    popup = folium.Popup(iframe, min_width=300, max_width=300)
    
    # Define icon color
    icon_color = station_color[row['starttime_buckets']]

    # Add each row to New Jersey base map
    folium.Marker(location=[row['start station latitude'],row['start station longitude']],
                  popup = popup, 
                  icon=folium.Icon(color=icon_color, icon='')).add_to(new_jersey_map)
    
new_jersey_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ebbbad242c1197043889592e3d3f633 {
#                     position: relative;
#                     width: 50.0%;
#                     height: 50.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ebbbad242c1197043889592e3d3f633&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ebbbad242c1197043889592e3d3f633 = L.map(
#                 &quot;map_2ebbbad242c1197043889592e3d3f633&quot;,
#                 {
#                     center: [40.693943, -73.98588],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2ebbbad242c1197043889592e3d3f633);
#
#
#
#
#
#             var tile_layer_698f7c4ade7b9c302a783c5bb1f2d0a9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2ebbbad242c1197043889592e3d3f633);
#
#
#             var marker_929e1fca0ded8c95a65fa3891c62e4b1 = L.marker(
#                 [40.73496102, -74.05950308],
#                 {}
#             ).addTo(map_2ebbbad242c1197043889592e3d3f633);
#
#
#             var icon_ea9f240b7ea9384cc86b10c304edb88d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_929e1fca0ded8c95a65fa3891c62e4b1.setIcon(icon_ea9f240b7ea9384cc86b10c304edb88d);
#
#
#         var popup_ca483eb51feb689e223eb0cb79672f15 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_2b10e0570cca3f843f056e2aaf0a5924 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBTdGFydCBTdGF0aW9uIE5hbWU6IDUgQ29ybmVycyBMaWJyYXJ5IAogVHJhZmZpYzogTG93ZXN0IFRyYWZmaWM=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_ca483eb51feb689e223eb0cb79672f15.setContent(i_frame_2b10e0570cca3f843f056e2aaf0a5924);
#
#
#
#         marker_929e1fca0ded8c95a65fa3891c62e4b1.bindPopup(popup_ca483eb51feb689e223eb0cb79672f15)
#         ;
#
#
#
#
#             var marker_2a39a23866bb343a76cdbd148994bde2 = L.marker(
#                 [40.7192822, -74.07126188],
#                 {}
#             ).addTo(map_2ebbbad242c1197043889592e3d3f633);
#
#
#             var icon_768bad3415b8da7db73ac0ad4c6ccf45 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2a39a23866bb343a76cdbd148994bde2.setIcon(icon_768bad3415b8da7db73ac0ad4c6ccf45);
#
#
#         var popup_2c9e8b54a3ba008be465d3c01cb18aec = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_b0986809dbcf87042a07da78b28df23b = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBTdGFydCBTdGF0aW9uIE5hbWU6IEFzdG9yIFBsYWNlIAogVHJhZmZpYzogTWVkaXVtIFRyYWZmaWM=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_2c9e8b54a3ba008be465d3c01cb18aec.setContent(i_frame_b0986809dbcf87042a07da78b28df23b);
#
#
#
#         marker_2a39a23866bb343a76cdbd148994bde2.bindPopup(popup_2c9e8b54a3ba008be465d3c01cb18aec)
#         ;
#
#
#
#
#             var marker_d3b3c271dbbae626a7f3696244255830 = L.marker(
#                 [40.7236589, -74.0641943],
#                 {}
#             ).addTo(map_2ebbbad242c1197043889592e3d3f633);
#
#
#             var icon_ea071616cacc41386eb6e12cc602ff9b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d3b3c271dbbae626a7f3696244255830.setIcon(icon_ea071616cacc41386eb6e12cc602ff9b);
#
#
#         var popup_7cdfb07f43844b9ef2a39ae0a58fbe7b = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_5a92e186a09dc2da83640e41e0ff96da = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;

# %% [markdown]
# #### Observations: Colors and popups successfully created.
# #### Marker Colors: black: Highest Traffic, dark blue: Medium High Traffic, blue: Medium Traffic, light blue: Low Traffic, white: Lowest Traffic

# %% [markdown]
# # 05. Heat Map

# %%
# Generate base map
def generateBaseMap(default_location=[40.693943, -73.985880], default_zoom_start=12): 
    base_map2 = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start, width='50%', height='50%', tiles = "Stamen Toner") 
    return base_map2

# %%
from folium.plugins import HeatMap
base_map2 = generateBaseMap() 
HeatMap(data=df_trips[['start station latitude', 'start station longitude', 'starttime_counts']].groupby(['start station latitude', 'start station longitude']).sum().reset_index().values.tolist(), radius=8, max_zoom=13).add_to(base_map2)

base_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4016a46f7271b94ea1e3a00275530b6c {
#                     position: relative;
#                     width: 50.0%;
#                     height: 50.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4016a46f7271b94ea1e3a00275530b6c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4016a46f7271b94ea1e3a00275530b6c = L.map(
#                 &quot;map_4016a46f7271b94ea1e3a00275530b6c&quot;,
#                 {
#                     center: [40.693943, -73.98588],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_4016a46f7271b94ea1e3a00275530b6c);
#
#
#
#
#
#             var tile_layer_c64e7d174d50ccb112e6fa3819787ffe = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4016a46f7271b94ea1e3a00275530b6c);
#
#
#             var heat_map_0cbb407b2c5faa7377b9a2f28a2df528 = L.heatLayer(
#                 [[40.70965083364061, -74.06860113143921, 1.0], [40.71113, -74.0789, 2819041.0], [40.7112423, -74.0557013, 358458489.0], [40.7124188237569, -74.03852552175522, 105740089.0], [40.7127742, -74.0364857, 24631369.0], [40.71346382669195, -74.06285852193832, 17197609.0], [40.7141454, -74.0335519, 80658361.0], [40.71435836870427, -74.06661093235016, 6822544.0], [40.71458403535893, -74.04281705617905, 240281001.0], [40.71517767732029, -74.03768330812454, 36421225.0], [40.71649, -74.04105, 11792356.0], [40.71653978099194, -74.0496379137039, 147233956.0], [40.71687, -74.03281, 196140025.0], [40.7177325, -74.043845, 119574225.0], [40.7182113, -74.0836394, 2896804.0], [40.71835519823214, -74.03891444206238, 67404100.0], [40.71848892, -74.047726625, 67240000.0], [40.7192517, -74.034234, 203119504.0], [40.71928220070702, -74.07126188278198, 16305444.0], [40.71942, -74.05099, 20322064.0], [40.71958611647166, -74.04311746358871, 656845641.0], [40.7211236, -74.03805095, 110019121.0], [40.72152515, -74.046304543, 76230361.0], [40.721630142638354, -74.04996782541275, 26553409.0], [40.72165072487999, -74.04288411140442, 36481600.0], [40.722103786686034, -74.07145500183105, 15202201.0], [40.72333158646436, -74.04595255851744, 46348864.0], [40.7236589, -74.0641943, 31393609.0], [40.7241765, -74.0506564, 41049649.0], [40.7242941, -74.0354826, 96294969.0], [40.7246050998869, -74.07840594649315, 34975396.0], [40.72528910781132, -74.04557168483734, 37100281.0], [40.7253399253558, -74.06762212514877, 43996689.0], [40.72568548362901, -74.04879033565521, 25230529.0], [40.72572613742557, -74.07195925712585, 16646400.0], [40.72601172964625, -74.05038893222809, 40195600.0], [40.7272235, -74.0337589, 212663889.0], [40.72755146730012, -74.07106071710587, 5276209.0], [40.727595966, -74.044247311, 279725625.0], [40.7287448, -74.0321082, 493728400.0], [40.73089709786179, -74.06391263008118, 248598289.0], [40.7311689, -74.0575736, 13756681.0], [40.73367, -74.0625, 12264004.0], [40.734785818, -74.050443636, 3786916.0], [40.73496102000952, -74.0595030784607, 3655744.0], [40.73520838045357, -74.04696375131607, 20548089.0], [40.7376037, -74.0524783, 7338681.0], [40.737711, -74.066921, 3316041.0], [40.742677141, -74.051788633, 15729156.0], [40.7443187, -74.0439909, 4721929.0], [40.74590996631558, -74.0572714805603, 1653796.0], [40.74871594538023, -74.04044330120087, 12292036.0]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 13, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 8}
#             ).addTo(map_4016a46f7271b94ea1e3a00275530b6c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 06. Results

# %% [markdown]
# #### Grove St. PATH, Newport Pkwy, and Liberty Light Rail are the most popular stations.
# #### JCBS Depot, Leonard Gordon Park, and Jackson Square are least popular.
# #### Many of the Citi Bike stations with the highest traffic are located near PATH (Port Authority Trans-Hudson), which is a rapid rail transit system that connects New Jersey with New York.

# %% [markdown]
# # 07. Export Data

# %%
# Export maps
map.save('plot_data_choro.html')
new_jersey_map.save('plot_data_choro2.html')
base_map2.save('plot_data_heat.html')

# %%
# Export df_trips as final_choropleth_data.csv
df_trips.to_csv(os.path.join(path, '02 Data','Prepared Data', 'final_choropleth_data.csv'), index = False)
